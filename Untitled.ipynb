# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# Replace 'your_file.xlsx' with the path to your Excel file
file_path = "C:\\Users\\amans\\OneDrive - IIT Kanpur\\Business Analytics\\Finlatics\\project_3\\AdvWorksData.xlsx"

# Read Sheet 1 of the Excel file into a DataFrame
df = pd.read_excel(file_path, sheet_name='Sheet1')

# Now 'df' contains the data from Sheet 1 in a Pandas DataFrame

# %%
df.head()
# Out:
#   productcategory productsubcategory                product   saleterritory  \
# 0        Clothing               Caps           AWC Logo Cap  United Kingdom
# 1     Accessories              Locks             Cable Lock  United Kingdom
# 2        Clothing             Gloves  Full-Finger Gloves, L  United Kingdom
# 3        Clothing             Gloves  Full-Finger Gloves, L  United Kingdom
# 4        Clothing             Gloves  Full-Finger Gloves, M  United Kingdom
#
#           Country    City     Sate      Customer     Employee  OrderCount  \
# 0  United Kingdom   Berks  England    Gary Suess  Amy Alberts           1
# 1  United Kingdom   Berks  England    Gary Suess  Amy Alberts           1
# 2  United Kingdom   Berks  England    Gary Suess  Amy Alberts           1
# 3  United Kingdom  London  England  Linda Martin  Amy Alberts           1
# 4  United Kingdom   Berks  England    Gary Suess  Amy Alberts           1
#
# ...

# %%
import datetime as dt

# %%
df.describe()
# Out:
#          OrderCount  StandardCost     UnitPrice  UnitPriceDiscount  \
# count  60880.000000  60841.000000  60880.000000       60880.000000
# mean       1.000641    454.410156    444.403298           0.005632
# std        0.038657    533.080133    519.954624           0.034797
# min        1.000000      0.856500      1.328200           0.000000
# 25%        1.000000     30.933400     34.925000           0.000000
# 50%        1.000000    204.625100    209.256000           0.000000
# 75%        1.000000    713.079800    672.294000           0.000000
# max        6.000000   2171.294200   2146.962000           0.400000
#
#            Discount     ListPrice  SaleswithStandard      NetSales  \
# count  60880.000000  60841.000000       60841.000000  60841.000000
# mean       8.664716    751.743296        1360.481428    -38.172509
# std       87.723102    879.068226        2217.403460    405.536877
# min        0.000000      2.290000           0.856500 -15099.745500
# ...

# %%
plt.plot(df['NetSales'])

# %% [raw]
# we can observe from the above data that sales value are going towards negative value.
# we need to clean the data .

# %%
df[df['NetSales']<0]
# Out:
#       productcategory productsubcategory                         product  \
# 0            Clothing               Caps                    AWC Logo Cap
# 13         Components    Mountain Frames   HL Mountain Frame - Black, 38
# 14         Components    Mountain Frames   HL Mountain Frame - Black, 42
# 15         Components    Mountain Frames  HL Mountain Frame - Silver, 38
# 16         Components    Mountain Frames  HL Mountain Frame - Silver, 42
# ...               ...                ...                             ...
# 60868           Bikes      Touring Bikes         Touring-3000 Yellow, 58
# 60869           Bikes      Touring Bikes         Touring-3000 Yellow, 58
# 60870           Bikes      Touring Bikes         Touring-3000 Yellow, 62
# 60871           Bikes      Touring Bikes         Touring-3000 Yellow, 62
# 60872           Bikes      Touring Bikes         Touring-3000 Yellow, 62
#
#         saleterritory         Country            City            Sate  \
# ...

# %%
#plt.plot(df['OrderCount'])
#df[df['OrderCount']<0]
#len(df['OrderCount'])
len(df['OrderCount'].isnull())
# Out:
# 60880

# %%
df[df['OrderCount'].isnull() & df['NetSales'].isnull()]
# Out:
# Empty DataFrame
# Columns: [productcategory, productsubcategory, product, saleterritory, Country, City, Sate, Customer, Employee, OrderCount, OrderDate, StandardCost, UnitPrice, UnitPriceDiscount, Discount, ListPrice, SaleswithStandard, NetSales, OrderQuantity, Sales]
# Index: []

# %%
df[df['OrderCount'].isnull()]
# Out:
# Empty DataFrame
# Columns: [productcategory, productsubcategory, product, saleterritory, Country, City, Sate, Customer, Employee, OrderCount, OrderDate, StandardCost, UnitPrice, UnitPriceDiscount, Discount, ListPrice, SaleswithStandard, NetSales, OrderQuantity, Sales]
# Index: []

# %%
len(df['OrderCount'].isnull())
# Out:
# 60880

# %%
len(df['OrderCount'].isnull() == False)
# Out:
# 60880

# %%
df['NetSales'] =  df['NetSales'].abs()
plt.plot(df['NetSales'])

# %%
plt.figure(figsize=(10,6),dpi=200)
plt.plot(df['Sales'])
plt.title('Sales')
# Out:
# Text(0.5, 1.0, 'Sales')

# %%
df.columns.isnull()
# Out:
# array([False, False, False, False, False, False, False, False, False,
#        False, False, False, False, False, False, False, False, False,
#        False, False])

# %%
file_path_2 = 'Cleaned_data.xlsx'



# Now save the changes back to the Excel file
df.to_excel(file_path, sheet_name='Sheet1', index=False)
# Out:
# ---------------------------------------------------------------------------
# PermissionError                           Traceback (most recent call last)
# Cell In[41], line 6
#       1 file_path_2 = 'Cleaned_data.xlsx'
#       5 # Now save the changes back to the Excel file
# ----> 6 df.to_excel(file_path, sheet_name='Sheet1', index=False)
#
# File ~\anaconda3\envs\MLenvironment\lib\site-packages\pandas\core\generic.py:2345, in NDFrame.to_excel(self, excel_writer, sheet_name, na_rep, float_format, columns, header, index, index_label, startrow, startcol, engine, merge_cells, encoding, inf_rep, verbose, freeze_panes, storage_options)
#    2332 from pandas.io.formats.excel import ExcelFormatter
#    2334 formatter = ExcelFormatter(
#    2335     df,
#    2336     na_rep=na_rep,
#    (...)
#    2343     inf_rep=inf_rep,
#    2344 )
# -> 2345 formatter.write(
#    2346     excel_writer,
#    2347     sheet_name=sheet_name,
#    2348     startrow=startrow,
# ...

# %%
cdf = pd.read_excel(file_path, sheet_name='Sheet1')
cdf.head()
# Out:
# ---------------------------------------------------------------------------
# PermissionError                           Traceback (most recent call last)
# Cell In[38], line 1
# ----> 1 cdf = pd.read_excel(file_path, sheet_name='Sheet1')
#       2 cdf.head()
#
# File ~\anaconda3\envs\MLenvironment\lib\site-packages\pandas\util\_decorators.py:311, in deprecate_nonkeyword_arguments.<locals>.decorate.<locals>.wrapper(*args, **kwargs)
#     305 if len(args) > num_allow_args:
#     306     warnings.warn(
#     307         msg.format(arguments=arguments),
#     308         FutureWarning,
#     309         stacklevel=stacklevel,
#     310     )
# --> 311 return func(*args, **kwargs)
#
# ...
